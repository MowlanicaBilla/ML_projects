# %%
import pandas_datareader as pdr
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_tesla = yf.download('TSLA')
print(df_tesla.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-06-12  171.119995  180.550003  169.800003  177.289993  177.289993
# 2024-06-13  188.389999  191.080002  181.229996  182.470001  182.470001
# 2024-06-14  185.800003  186.000000  176.919998  178.009995  178.009995
# 2024-06-17  177.919998  188.809998  177.000000  187.440002  187.440002
# 2024-06-18  186.559998  187.199997  182.369995  184.860001  184.860001
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-12  171.119995  180.550003  169.800003  177.289993  177.289993
# 2024-06-13  188.389999  191.080002  181.229996  182.470001  182.470001
# 2024-06-14  185.800003  186.000000  176.919998  178.009995  178.009995
# 2024-06-17  177.919998  188.809998  177.000000  187.440002  187.440002
# 2024-06-18  186.559998  187.199997  182.369995  184.860001  184.860001
#
#                Volume
# Date
# 2024-06-12   90389400
# 2024-06-13  118984100
# 2024-06-14   82038200
# 2024-06-17  109786100
# 2024-06-18   68853400

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2023-01-01','2024-06-10'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2023-01-01','2024-06-10'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2023-01-01','2024-06-10'],ylim=[0,900],figsize=(12,4),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
# Plot broadcast indexing
'''
Broadcast indexing simplifies operations on arrays with different shapes and is widely used in numerical computing and data visualization. 
It allows for efficient and concise code when manipulating and plotting data, enabling operations like conditional formatting, grid-based function evaluations, and more.

Suppose you want to highlight all days where the 'High' value was greater than 800 in a different color. Here's how broadcasting can help:

1. Create a condition mask using broadcasting.
2. Use the mask to plot with different styles or colors.
'''

# Assuming df_tesla is already defined and contains the necessary data
# For demonstration, let's create a sample DataFrame similar to df_tesla
dates = pd.date_range(start='2023-01-01', end='2024-06-10', freq='B')
high_values = np.random.uniform(500, 900, len(dates))
high_df = pd.DataFrame({'High': high_values}, index=dates)

# Define a threshold for highlighting
threshold = 800

# Create a mask for the condition
mask = high_df['High'] > threshold

# Plot the main series
plt.figure(figsize=(12, 4))
high_df['High'].plot(xlim=['2023-01-01', '2024-06-10'], ylim=[0, 1000], ls='--', c='green', label='High')

# Plot the highlighted points
plt.scatter(high_df.index[mask], high_df['High'][mask], color='red', label=f'High > {threshold}')

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('High Value')
plt.title('Tesla High Prices with Highlighted Points')
plt.legend()

plt.show()

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-06-05', '2024-06-06', '2024-06-07', '2024-06-10',
#                '2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14',
#                '2024-06-17', '2024-06-18'],
#               dtype='datetime64[ns]', name='Date', length=3517, freq=None)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-06-12  171.119995  180.550003  169.800003  177.289993  177.289993
# 2024-06-13  188.389999  191.080002  181.229996  182.470001  182.470001
# 2024-06-14  185.800003  186.000000  176.919998  178.009995  178.009995
# 2024-06-17  177.919998  188.809998  177.000000  187.440002  187.440002
# 2024-06-18  186.559998  187.199997  182.369995  184.860001  184.860001
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
index=df_tesla.loc['2023-01-01':'2024-06-19'].index
share_open=df_tesla.loc['2023-01-01':'2024-06-19']['Open']

# %%
share_open
# Out:
# Date
# 2023-01-03    118.470001
# 2023-01-04    109.110001
# 2023-01-05    110.510002
# 2023-01-06    103.000000
# 2023-01-09    118.959999
#                  ...
# 2024-06-12    171.119995
# 2024-06-13    188.389999
# 2024-06-14    185.800003
# 2024-06-17    177.919998
# 2024-06-18    186.559998
# Name: Open, Length: 367, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2024-06-05', '2024-06-06', '2024-06-07', '2024-06-10',
#                '2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14',
#                '2024-06-17', '2024-06-18'],
#               dtype='datetime64[ns]', name='Date', length=367, freq=None)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %% [markdown]
# ## Datetime Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3512 2024-06-12  171.119995  180.550003  169.800003  177.289993  177.289993
# 3513 2024-06-13  188.389999  191.080002  181.229996  182.470001  182.470001
# 3514 2024-06-14  185.800003  186.000000  176.919998  178.009995  178.009995
# 3515 2024-06-17  177.919998  188.809998  177.000000  187.440002  187.440002
# 3516 2024-06-18  186.559998  187.199997  182.369995  184.860001  184.860001
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3517 entries, 0 to 3516
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3517 non-null   datetime64[ns]
#  1   Open       3517 non-null   float64
#  2   High       3517 non-null   float64
#  3   Low        3517 non-null   float64
#  4   Close      3517 non-null   float64
#  5   Adj Close  3517 non-null   float64
#  6   Volume     3517 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.5 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 6, 19, 12, 18, 32, 426003)

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ### Time Resampling

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.resample(rule='A').min()
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/2338822268.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').min()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# ...

# %%
df_tesla.resample(rule='A').max()
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/3203370108.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# ...

# %%
##year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/3654829475.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()['Open'].plot()
# <Axes: xlabel='Date'>

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/2028374030.py:3: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tesla.resample(rule='BA').max()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-30    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-30   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# ...

# %%
df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-03    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-03    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-02    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-02    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-02    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
##plotting
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/2438607900.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(35,6))
# Out:
# /var/folders/bk/1644ckzd4z1_dg2l6_nrn3cr0000gp/T/ipykernel_83628/3160943044.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(35,6))
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].rolling(11).max().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13         NaN
# 2010-07-14    2.028000
# 2010-07-15    2.028000
# 2010-07-16    1.728000
# 2010-07-19    1.540000
# 2010-07-20    1.483333
# 2010-07-21    1.483333
# 2010-07-22    1.483333
# 2010-07-23    1.483333
# 2010-07-26    1.483333
# 2010-07-27    1.483333
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# * Open: 30 days rolling is the smoothed out version of Open

# %% [markdown]
# In time series forecasting, rolling and expanding windows are two techniques used to create smaller time series datasets from a larger one. The main difference between the two lies in how they handle the window size and the way they extract features.
#
# ### Rolling Window
#
# A rolling window is a fixed-size window that slides over the time series data, extracting features at each step. The window size is constant, and the window moves one time step at a time. This means that the features extracted at each step are based on the same number of previous time steps.
#
# For example, if you have a time series with 100 observations and a rolling window of size 10, the first window would be from observation 1 to 10, the second window would be from observation 2 to 11, and so on.
#
# ### Expanding Window
#
# An expanding window, on the other hand, is a window that grows in size as it moves over the time series data. The window size increases by one time step at each step, allowing the model to incorporate more recent data.
#
# For example, if you have a time series with 100 observations and an expanding window, the first window would be from observation 1 to 10, the second window would be from observation 1 to 11, the third window would be from observation 1 to 12, and so on.
#
# ### Key differences
#
# Here are the key differences between rolling and expanding windows:
#
# * Window size: Rolling window has a fixed size, while expanding window grows in size as it moves over the data.
# * Feature extraction: Rolling window extracts features based on a fixed number of previous time steps, while expanding window extracts features based on a growing number of previous time steps.
# * Data incorporation: Rolling window incorporates the same amount of data at each step, while expanding window incorporates more recent data as it moves forward.
# When to use each
#
# ### Rolling windows are suitable when:
#
# * The time series has a stable trend and seasonality.
# * The most recent data is not as important for forecasting.
# * You want to extract features based on a fixed number of previous time steps.
#
# ### Expanding windows are suitable when:
#
# * The time series is volatile or has a strong trend.
# * The most recent data is important for forecasting.
# * You want to incorporate more recent data into your model.
#
# In summary, rolling windows are useful when you want to extract features based on a fixed number of previous time steps, while expanding windows are useful when you want to incorporate more recent data into your model.

# %% [markdown]
# 1. Upward trend
# 2. Downward trend
# 3. Stationary data
# 4. Seasonality
# 5. Cyclic data
# 6. What is Forecasting vs Prediction.?
# 7. Evaluation metrics of Time-series
# 8. Mean Average (Rolling window)
# 9. Exponential Weight Moving Average
# 10. Error Trend Seasonality
# 11. ARIMA
# 12. SARIMA, SARIMAX
# 13. ACF, PACF
# 14. Multivariate Time Series
# 15. FBProphet
# 16. Hierarchical Time Series
# 17.
